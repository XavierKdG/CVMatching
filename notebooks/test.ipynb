# %%
import pandas as pd
import numpy as np

# %%
# df1 = pd.read_csv('../data/raw/job_descriptions.csv')
# df1.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df1 = pd.read_csv('../CVMatching-1/data/raw/job_descriptions.csv')
#       2 df1.head()
#
# File c:\Users\xavie\miniconda3\envs\cvmatching\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\xavie\miniconda3\envs\cvmatching\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
df2 = pd.read_csv('../data/raw/job_descriptions2.csv')
df2.head()
# Out:
#    Job ID                          Agency Posting Type  # Of Positions  \
# 0   87990    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 1   97899    DEPARTMENT OF BUSINESS SERV.     Internal               1
# 2  102221  DEPT OF ENVIRONMENT PROTECTION     External               1
# 3  102221  DEPT OF ENVIRONMENT PROTECTION     Internal               1
# 4  114352  DEPT OF ENVIRONMENT PROTECTION     Internal               5
#
#                              Business Title             Civil Service Title  \
# 0                           Account Manager  CONTRACT REVIEWER (OFFICE OF L
# 1  EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT  ADMINISTRATIVE BUSINESS PROMOT
# 2                        Project Specialist  ENVIRONMENTAL ENGINEERING INTE
# 3                        Project Specialist  ENVIRONMENTAL ENGINEERING INTE
# 4                        Deputy Plant Chief  SENIOR STATIONARY ENGINEER (EL
#
#   Title Code No Level Job Category Full-Time/Part-Time indicator  ...  \
# ...

# %%
df2.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df1.columns
#
# NameError: name 'df1' is not defined

# %%
df2['Residency Requirement'].value_counts()
# df2[df2["Residency Requirement"] == "Work location: 33 Whitehall St"]
# Out:
# New York City residency is generally required within 90 days of appointment. However, City Employees in certain titles who have worked for the City for 2 continuous years may also be eligible to reside in Nassau, Suffolk, Putnam, Westchester, Rockland, or Orange County. To determine if the residency requirement applies to you, please discuss with the agency representative at the time of interview.                                                                                                                                                           2083
# ...
