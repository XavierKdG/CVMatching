# %%
# !pip install peft
# Out:
# Collecting peft
#   Downloading peft-0.18.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from peft) (25.0)
# Requirement already satisfied: psutil in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from peft) (7.1.2)
# Requirement already satisfied: pyyaml in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from peft) (6.0.3)
# Requirement already satisfied: torch>=1.13.0 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from peft) (2.8.0)
# Requirement already satisfied: transformers in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from peft) (4.36.2)
# Requirement already satisfied: tqdm in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from peft) (4.67.1)
# Collecting accelerate>=0.21.0 (from peft)
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: safetensors in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from peft) (0.6.2)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from peft) (0.36.0)
# Requirement already satisfied: filelock in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (1.2.0)
# Requirement already satisfied: requests in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (2.32.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (4.15.0)
# Requirement already satisfied: setuptools in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from torch>=1.13.0->peft) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.5)
# Requirement already satisfied: jinja2 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2025.10.5)
# Requirement already satisfied: regex!=2019.12.17 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from transformers->peft) (2025.10.23)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/admin-groep10/CV-Matching/miniconda3/envs/cvmatching/lib/python3.12/site-packages (from transformers->peft) (0.15.2)
# Downloading peft-0.18.0-py3-none-any.whl (556 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 556.4/556.4 kB 4.6 MB/s  0:00:00
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
# Installing collected packages: accelerate, peft
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [peft]1/2 [peft]
# Successfully installed accelerate-1.12.0 peft-0.18.0

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel
import torch

# Load base model and tokenizer
base_model_name = "meta-llama/Llama-3.1-8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(base_model_name)
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_name,
    torch_dtype=torch.float16,
    device_map="auto",
    trust_remote_code=True
)

# Load and apply the LoRA adapter
adapter_path = "./path/to/your/adapter"  # Path to your adapter
model = PeftModel.from_pretrained(base_model, adapter_path)

# Generate text
prompt = "What is the formula for the Black-Scholes model?"
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=512,
        # This ensures that you get reproducible responses.
        temperature=0,
        pad_token_id=tokenizer.eos_token_id
    )

response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(response)
